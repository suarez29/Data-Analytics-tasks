# %%
# Importando librerias

import sys
import keyword
import operator
from datetime import datetime
import os

# %% [markdown]
# # Ejercicio # 1
#
# # >El Ejercicio 1, es genere ventas de los ultimos dias y muestre por pantalla una serie(dataframe) con los datos de las ventas por productos.

# %%
# importamos las librerías
import numpy as np
import pandas as pd

# %%
"""
Ejercicio 1 : Generar ventas de los ultimos 5 dias

1. creamos importamos las librerias numpy y pandas.
el panda utilisamos para crear un dataframe con los datos de las ventas y productos.
el numpy importamos para las calculos matematicos.

2.  creamos una dataframe
-creamos una semilla np.random.seed() utilisamos 1234510 como parametro. Pero puede ser otro numero
-llamamos a pandas y llamamos a dataframe con el nombre df1
-para el index utilisamos fecha con rango asta 10. esto qiere decir que la fecha comienza de la dia 1 asta 10.
-creamos una lista con elementos Ventas, Productos Unidades y precio a unidad
- a el df1 (dataframe) utilizando assign para asignar a un lista de productos a la columna productos
- a el df1 (dataframe) utilizando assign para asignar a un lista de unidades a la columna unidades
- a el df1 (dataframe) utilizando assign para asignar a un lista de precio a unidad a la columna precio_unidad
- para calcular utilizamos a labda y asignamos el calculo de Unidades * Precio_unidad a la columna Ventas
"""


np.random.seed(1234510)

df1 = pd.DataFrame(
        index=pd.date_range("20220101", periods=10),
        columns = ['Ventas','Productos', 'Unidades', 'Precio_unidad',]
        )
df1 = df1.assign(Productos=['Ventilador','Direct Tv','Cama','Labadora','bycicleta','armario','sartenes','sofa','iphone','estufa'])
df1 = df1.assign(Unidades=[50,60,20,20,30,20,10,45,100,10])
df1 = df1.assign(Precio_unidad=[100,1200,2000,3000,1000,3000,700,60,1000,900])

df1=(
    df1
    .assign(Ventas= lambda x: x.Unidades*x.Precio_unidad)

)

df1
# Out:
#             Ventas   Productos  Unidades  Precio_unidad
# 2022-01-01    5000  Ventilador        50            100
# 2022-01-02   72000   Direct Tv        60           1200
# 2022-01-03   40000        Cama        20           2000
# 2022-01-04   60000    Labadora        20           3000
# 2022-01-05   30000   bycicleta        30           1000
# 2022-01-06   60000     armario        20           3000
# 2022-01-07    7000    sartenes        10            700
# 2022-01-08    2700        sofa        45             60
# 2022-01-09  100000      iphone       100           1000
# 2022-01-10    9000      estufa        10            900

# %%
df1[5:] # Para llamar los ultimos ventas llamamos el dataframe con el nombre df1, y despues con el index 5: a 10 para las 5 ultimos dias
# Out:
#             Ventas Productos  Unidades  Precio_unidad
# 2022-01-06   60000   armario        20           3000
# 2022-01-07    7000  sartenes        10            700
# 2022-01-08    2700      sofa        45             60
# 2022-01-09  100000    iphone       100           1000
# 2022-01-10    9000    estufa        10            900

# %% [markdown]
# # Ejercicio 2
# Reciba un dictionario con los ingresos mensuales de los clientes de una impresa, y devuelva una serie con ingreso minimo, maximo y media

# %%
"""""
Ejercicio 2
Aqui tambien importamos las librerias numpy y pandas para los calculos matematicos,
y pandas para crear el dataframe.

1. creamos un diccionario con los ingresos mensuales de los clientes de una impresa
En un dictionario se tiene un key y un valor, el key es el funcion del cliente y el valor es el ingreso mensual.
2. creamos contenedores para los calculos matematicos
Para la suma total utitlizamos sum ,con el nombre del dictionario y sus valores para calcular el total de ingresos
3. calculamos la media con utilizando el calculo total de ingresos y devidido entre (len) que el cantidad de los keys
para el minimo utilizamos min con el parametro del dictionario y sus valores
para el maximo utilizamos max con el parametro del dictionario y sus valores
"""

import numpy as np
import pandas as pd

dicIngreso = {
    "Director": 16000,
    "Secretaria":5000,
    "Vendedor": 10000,
    "Mecanico": 8000,
    "Vendedor de priesas": 12000,
}


total = sum(dicIngreso.values()) #creamos una variable para el calculo de la suma total
media = total/len(dicIngreso) #creamos una variable para el calculo de la media
minimo = min(dicIngreso.values())#creamos una variable para el calculo minimal
maximo = max(dicIngreso.values())# creamos una variable para el calculo max
a = (total,media,minimo,maximo) #creamos una tupla con los calculos matematicos
pd.Series(a)# el pd de pandas para crear los datos en una series
# Out:
# 0    51000.0
# 1    10200.0
# 2     5000.0
# 3    16000.0
# dtype: float64

# %% [markdown]
# # Ejercicio 3
# Ecribir programa que genere y muestre por pantalla un Dataframe con los datos

# %%
"""
Ejercicio 3
Aqui tambien importamos las librerias numpy y pandas para los calculos matematicos,
y pandas para crear el dataframe.

1. creamos un dictionario con una lista de datos
2. creamos un dataframe con el nombre df2
"""
import numpy as np
import pandas as pd
Empresa = {
    "Mes": ["Enero","Febrero","Marzo","Abril","Mayo"],
    "Ventas":[30500, 35600, 28300, 33900, 42500],
    "Gastos" : [22000, 23450, 18100, 35700, 32450]
}

df2 = pd.DataFrame(Empresa)


df2
# Out:
#        Mes  Ventas  Gastos
# 0    Enero   30500   22000
# 1  Febrero   35600   23450
# 2    Marzo   28300   18100
# 3    Abril   33900   35700
# 4     Mayo   42500   32450

# %% [markdown]
# # Ejercicio 3.1
# Columna 1 = Gasto/Ventas*100

# %%
df2['Columna1'] = df2['Gastos'] / df2['Ventas']*100 # agregamos en la lista  de las columna el nombre Columna1 y con el nombre del las columnas Gastos y Ventas dividimos y despues muliplicamos
df2
# Out:
#        Mes  Ventas  Gastos    Columna1
# 0    Enero   30500   22000   72.131148
# 1  Febrero   35600   23450   65.870787
# 2    Marzo   28300   18100   63.957597
# 3    Abril   33900   35700  105.309735
# 4     Mayo   42500   32450   76.352941

# %% [markdown]
# #Ejercicio 3.2
# Columna 2 = Si Ventas>= 30000, imprimir Meta superada, caso contrario imprimir Meta no superada

# %%
"""
Como anterior nececitamos a la libreria numpy para los calculos matematicos
1. creamos un funcion de assign los valores de la columna Ventas
aque utilizamos if else statement para asignar los valores a la columna Columna2
si Ventas >= 30000, imprimir Meta superada, caso contrario imprimir Meta no superada
"""
import numpy as np
def assign_value(Ventas):
    if Ventas >= 30000:
        return "Meta Superada"
    else:
        return "Meta No Superada"
"""
con el apply aplicamos la funcion a la columna Ventas para que asignar los valores a la columna Columna2
"""
df2['Columna2'] = df2['Ventas'].apply(assign_value)
df2
# Out:
#        Mes  Ventas  Gastos  Columna1          Columna2
# 0    Enero   30500   22000  0.721311     Meta Superada
# 1  Febrero   35600   23450  0.658708     Meta Superada
# 2    Marzo   28300   18100  0.639576  Meta No Superada
# 3    Abril   33900   35700  1.053097     Meta Superada
# 4     Mayo   42500   32450  0.763529     Meta Superada

# %% [markdown]
# #Ejercicio 3.3
# Calcula el sobre gasto de los ultimos 3 meses

# %%
"""

1. Utilisamos assign para asignar a la columna(columna3) sobre gasto el calculo de Gastos - Ventas
- Con Columna 3 crea una columna en el dataframe para guardar el calculo de Gastos - Ventas
"""
import numpy as np
df2=(
    df2
    .assign(Columna3 = lambda x: x.Gastos - x.Ventas)
)
df2
# Out:
#        Mes  Ventas  Gastos    Columna1  Columna3
# 0    Enero   30500   22000   72.131148     -8500
# 1  Febrero   35600   23450   65.870787    -12150
# 2    Marzo   28300   18100   63.957597    -10200
# 3    Abril   33900   35700  105.309735      1800
# 4     Mayo   42500   32450   76.352941    -10050

# %% [markdown]
# # Ejercicio 3.4
# Obtener el total de las ventas de los ultimos 3 meses

# %%
"""
con el nombre tail guaramos en la variable tail las ultimas 3 filas del dataframe df2
despues con el nombre ultimos_ventas utilizamos el metodo sum para sumar los valores de la columna Ventas
"""
tail = df2.tail(3)# el tail muestra por default las ultimas 5 filas, si nostros ponemos 3, le saca los ultimos 3
ultimo_ventas = tail['Ventas'].sum()# para el total los ultimos 3 meses de las ventas utilizamos .sum para sumar los elementos dentro del columna ventas
print('Total ventas de los ultimos 3 meses es', ultimo_ventas)# para informar utilizamos print con un string y el nombre del contenedor
# Out:
# Total ventas de los ultimos 3 meses es 104700

# %% [markdown]
# # Ejercicio 3.5
# Obtener el total de gastos de febrero a abril

# %%
"""
convertimos el dataframe en un array para poder hacer los calculos matematicos
"""
df2 = np.array(df2)
df2
# Out:
# array([['Enero', 30500, 22000, 0.7213114754098361, 'Meta Superada',
#         -8500],
#        ['Febrero', 35600, 23450, 0.6587078651685393, 'Meta Superada',
#         -12150],
#        ['Marzo', 28300, 18100, 0.6395759717314488, 'Meta No Superada',
#         -10200],
#        ['Abril', 33900, 35700, 1.0530973451327434, 'Meta Superada', 1800],
#        ['Mayo', 42500, 32450, 0.7635294117647059, 'Meta Superada',
#         -10050]], dtype=object)

# %%
df2.shape
# Out:
# (5, 6)

# %%
"""
Imprimimos el total de gastos de febrero a abril
Tien 2 dimenciones de tipo forward, utilizamos los indices y columnas para obtener los valores para el calculo
"""
print("Total Gastos de febrero a abril es:",df2[1,2]+df2[2,2]+df2[3,2])
# Out:
# Total Gastos de febrero a abril es: 77250

# %% [markdown]
# # Ejercicio 4
# cargar el fichero datos_seguros
# 1.Genera un data frame con los datos del fichero
# 2.Mostrat por pantalla las dimensiones del Dataframe, el numero de datos que contiene, los nombres de sus columnas y filas, los tipos de datos de las columnas, mostrar las 10 primeras fillas y las 10 ultimas filas, verificar si tiene datos perdidos/nulos
# 3 Extraer las 1000 primeras filas almacenarlas en un contenedor

# %%
"""
Ejercicio 4
porque estoy acustumbrado con colab utilisamos from google.colab import files para cargar el fichero csv
De cargamos el fichero datos_seguros.csv en un dataframe con el nombre df4
"""
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5511604d-4edf-486f-b48b-17b1b1568933" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5511604d-4edf-486f-b48b-17b1b1568933">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir data# creamos un carpeta para el fichero

# %%
"""
Ejercicio 4.1
"""

"""
utilisamos panda para leer desde el carpeta donde el fichero csv esta guardado y lo guardamos en el dataframe con un seperador ;
"""
import pandas as pd
df4 = pd.read_csv('/content/data/datos_seguros.csv', sep=';')
df4
# Out:
#        MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0      201506             0              3.0           0.0        2300.0
# 1      201506             0              2.0        3215.0        3500.0
# 2      201506             0              1.0        3169.0        5000.0
# 3      201506             1              1.0        6495.0        8450.0
# 4      201506             0              NaN           NaN           NaN
# ...       ...           ...              ...           ...           ...
# 45793  201505             0              2.0           0.0           0.0
# 45794  201505             0              NaN           NaN           NaN
# 45795  201506             0              NaN           NaN           NaN
# 45796  201506             0              NaN           NaN           NaN
# 45797  201506             0              1.0           0.0           0.0
#
#        USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  \
# ...

# %%
"""
Ejercicio 4.2
Para saber la forma del dataframe utilizamos el metodo ndim que nos devuelve el numero de dimensiones del dataframe que es 2.
Los indexes y columnas son 2 dimensiones
"""
df4.ndim
# Out:
# 2

# %%
"""
con ela methodo shape nos da la forma de 45798 filas y 17 columnas en el dataframe
"""
df4.shape
# Out:
# (45798, 17)

# %%
"""
Con el methodo info nos da informacion de las columnas, typo de data y data que no es nulo del dataframe
"""
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45798 entries, 0 to 45797
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MES_T0                   45798 non-null  int64
#  1   VENTA_SEGURO             45798 non-null  int64
#  2   NUM_TC_TOTAL_T2          25397 non-null  float64
#  3   SALDO_BCO_T2             25452 non-null  float64
#  4   LINEA_BCO_T2             25452 non-null  float64
#  5   USO_LINEA_BCO_T2         25452 non-null  float64
#  6   Nro_CTa_Ahorro_Bco_T1    44405 non-null  float64
#  7   Ahorro_Sldo_Bco_T1       44405 non-null  float64
#  8   monto_ope_t2             32927 non-null  float64
#  9   PROM_ANUAL_MTO_OPERA     32927 non-null  float64
#  10  MAX_MTO_OPERA_Anual      32927 non-null  float64
#  11  Ratio_HospvsMtoTotal_t2  29719 non-null  float64
#  12  SEXO                     45798 non-null  object
#  13  ANTIGUEDAD_MES           45798 non-null  int64
# ...

# %%
"""
Con el methodo head nos da las primeras 10 filas del dataframe si  pasamos un numero como parametro.
"""
df4.head(10)
# Out:
#    MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0  201506             0              3.0           0.0        2300.0
# 1  201506             0              2.0        3215.0        3500.0
# 2  201506             0              1.0        3169.0        5000.0
# 3  201506             1              1.0        6495.0        8450.0
# 4  201506             0              NaN           NaN           NaN
# 5  201506             0              3.0        2373.0        9373.0
# 6  201506             0              2.0           0.0           0.0
# 7  201506             0              1.0        3023.0       16720.0
# 8  201506             0              1.0        1931.0       12500.0
# 9  201506             0              NaN           NaN           NaN
#
#    USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  monto_ope_t2  \
# 0          0.000000                    0.0                 0.0         15.00
# ...

# %%
'''
Con el methodo tail nos da las ultimas 10 filas del dataframe si  pasamos un numero como parametro.
'''
df4.tail(10)
# Out:
#        MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 45788  201505             0              4.0           0.0           0.0
# 45789  201505             0              1.0           0.0           0.0
# 45790  201505             0              2.0           0.0           0.0
# 45791  201506             0              1.0           0.0           0.0
# 45792  201505             0              2.0           0.0       12000.0
# 45793  201505             0              2.0           0.0           0.0
# 45794  201505             0              NaN           NaN           NaN
# 45795  201506             0              NaN           NaN           NaN
# 45796  201506             0              NaN           NaN           NaN
# 45797  201506             0              1.0           0.0           0.0
#
#        USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  \
# 45788               0.0                    0.0                 0.0
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45798 entries, 0 to 45797
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   MES_T0                   45798 non-null  int64
#  1   VENTA_SEGURO             45798 non-null  int64
#  2   NUM_TC_TOTAL_T2          25397 non-null  float64
#  3   SALDO_BCO_T2             25452 non-null  float64
#  4   LINEA_BCO_T2             25452 non-null  float64
#  5   USO_LINEA_BCO_T2         25452 non-null  float64
#  6   Nro_CTa_Ahorro_Bco_T1    44405 non-null  float64
#  7   Ahorro_Sldo_Bco_T1       44405 non-null  float64
#  8   monto_ope_t2             32927 non-null  float64
#  9   PROM_ANUAL_MTO_OPERA     32927 non-null  float64
#  10  MAX_MTO_OPERA_Anual      32927 non-null  float64
#  11  Ratio_HospvsMtoTotal_t2  29719 non-null  float64
#  12  SEXO                     45798 non-null  object
#  13  ANTIGUEDAD_MES           45798 non-null  int64
# ...

# %%
"""
creamos  nombre de un variable para el calculo de los nulos por columna.
isna es para filtrar los datos nulos(NAN) o el boolean true y el sum es para sumar los valores nulos.
Despues utilizamos el metodo sort_values para ordenar los valores de forma ascendente
De esta manera podemos verificar los datos nulos por columna
"""
a = df4.isna().sum()
a.sort_values(ascending=False)
# Out:
# NUM_TC_TOTAL_T2            20401
# SALDO_BCO_T2               20346
# LINEA_BCO_T2               20346
# USO_LINEA_BCO_T2           20346
# Ratio_HospvsMtoTotal_t2    16079
# monto_ope_t2               12871
# PROM_ANUAL_MTO_OPERA       12871
# MAX_MTO_OPERA_Anual        12871
# Nro_CTa_Ahorro_Bco_T1       1393
# Ahorro_Sldo_Bco_T1          1393
# ANTIGUEDAD_MES                 0
# SOW_BCO_T2                     0
# DEPARTAMENTO                   0
# MES_T0                         0
# SEXO                           0
# VENTA_SEGURO                   0
# SOW_BCO_SEMESTRAL              0
# dtype: int64

# %%
first_1000 = df4.head(1000)#con el methodo head por default saca los primeros 5 filas, y si agregamos 1000 como variable sacamos los primeros 1000 filas del dataframe
first_1000
# Out:
#      MES_T0  VENTA_SEGURO  NUM_TC_TOTAL_T2  SALDO_BCO_T2  LINEA_BCO_T2  \
# 0    201506             0              3.0           0.0        2300.0
# 1    201506             0              2.0        3215.0        3500.0
# 2    201506             0              1.0        3169.0        5000.0
# 3    201506             1              1.0        6495.0        8450.0
# 4    201506             0              NaN           NaN           NaN
# ..      ...           ...              ...           ...           ...
# 995  201506             0              1.0        4357.0        4600.0
# 996  201506             0              NaN           NaN           NaN
# 997  201506             0              NaN           NaN           NaN
# 998  201506             0              1.0           0.0           0.0
# 999  201506             0              4.0           0.0           0.0
#
#      USO_LINEA_BCO_T2  Nro_CTa_Ahorro_Bco_T1  Ahorro_Sldo_Bco_T1  \
# ...
